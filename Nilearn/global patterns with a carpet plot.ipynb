# %%
# references 
# https://nilearn.github.io/auto_examples/01_plotting/plot_carpet.html#sphx-glr-auto-examples-01-plotting-plot-carpet-py 
# A common quality control step for functional MRI data is to visualize the data over time in a carpet plot (also known as a Power plot or a grayplot)

# %%
from nilearn import datasets

adhd_dataset = datasets.fetch_adhd(n_subjects=1)

print(dir(adhd_dataset))
print()

# Print basic information on the dataset
print('First subject functional nifti image (4D) is at: %s' %
      adhd_dataset.func[0])  # 4D data
# Out:
# ['confounds', 'description', 'func', 'phenotypic']
#
# First subject functional nifti image (4D) is at: /Users/vaibhavsharma/nilearn_data/adhd/data/0010042/0010042_rest_tshift_RPI_voreg_mni.nii.gz

# %%
from nilearn import masking

# Build an EPI-based mask because we have no anatomical data
mask_img = masking.compute_epi_mask(adhd_dataset.func[0])

# %%
# Visualizing global patterns over time

import matplotlib.pyplot as plt

from nilearn.plotting import plot_carpet

display = plot_carpet(adhd_dataset.func[0], mask_img)

display.show()
# Out:
# <ipython-input-5-2a387f72233d>:9: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   display.show()
