# %%
# reference 
# https://nilearn.github.io/auto_examples/01_plotting/plot_atlas.html#sphx-glr-auto-examples-01-plotting-plot-atlas-py

# %%
from nilearn import datasets

dataset = datasets.fetch_atlas_harvard_oxford('cort-maxprob-thr25-2mm')

print(dir(dataset))

atlas_filename = dataset.maps

print('Atlas ROIs are located at: %s' % atlas_filename)
# Out:
# ['labels', 'maps']
# Atlas ROIs are located at: /Users/vaibhavsharma/nilearn_data/fsl/data/atlases/HarvardOxford/HarvardOxford-cort-maxprob-thr25-2mm.nii.gz

# %%
# Visualizing the Harvard-Oxford atlas 

from nilearn import plotting
plotting.plot_roi(atlas_filename, title="Harvard Oxford atlas")

# %%
# Visualizing the Harvard-Oxford atlas with contours 

plotting.plot_roi(atlas_filename, view_type='contours',
                  title="Harvard Oxford atlas in contours")
plotting.show()
# Out:
# /Users/vaibhavsharma/opt/anaconda3/envs/mcgill/lib/python3.8/site-packages/nilearn/plotting/displays.py:97: UserWarning: No contour levels were found within the data range.
#   im = getattr(ax, type)(data_2d.copy(),
