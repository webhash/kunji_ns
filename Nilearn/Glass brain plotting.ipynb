# %%
# references 
# https://nilearn.github.io/auto_examples/01_plotting/plot_demo_glass_brain.html#sphx-glr-auto-examples-01-plotting-plot-demo-glass-brain-py

# %%
from nilearn import datasets

motor_images = datasets.fetch_neurovault_motor_task()
print(dir(motor_images))
stat_img = motor_images.images[0]
# Out:
# ['collections_meta', 'description', 'images', 'images_meta']

# %%
from nilearn import plotting

plotting.plot_glass_brain(stat_img, threshold=3)

# %%
for item in motor_images.images:
    plotting.plot_glass_brain(item)
plotting.show()

# %%
# Glass brain plotting: black background
plotting.plot_glass_brain(
    stat_img, title='plot_glass_brain',
    black_bg=True, display_mode='xz', threshold=3)

# %%
from nilearn.image import mean_img
mi = mean_img(motor_images.images)
type(mi)
# Out:
# nibabel.nifti1.Nifti1Image

# %%
# plotting mean images
plotting.plot_glass_brain(
    mi, title='plot_glass_brain',
    black_bg=True, display_mode='xz', threshold=1)

# %%
# Glass brain plotting: Hemispheric sagittal cuts
plotting.plot_glass_brain(stat_img,
                          title='plot_glass_brain with display_mode="lyrz"',
                          display_mode='lyrz', threshold=2)

plotting.show()

# %%
plotting.plot_glass_brain(mi,
                          title='plot_glass_brain with display_mode="lyrz"',
                          display_mode='lyrz', threshold=2)

plotting.show()
